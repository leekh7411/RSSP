# %%
import os
import matplotlib.pyplot as plt
# Train on CPU (hide GPU) due to memory constraints
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
from global_dict import DATASET_PATH, HYPER_PARAMS
from preprocess import *
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#preprocess_and_save(TEXT_LOGS=True, PLT_LOGS=True)

# %%
X, A, Y, L = load_rna_ss_dataset(PLT_LOGS=True)
# Out:
# Load npz type dataset: /datasets/preprocessed/PDB.npz
# - keys: ['L', 'Y', 'A', 'X']
# - (X) sequence  features shape: (1059,)
# - (A) backbone  features shape: (1059,)
# - (Y) structure features shape: (1059,)
# - (L) sequence  length   shape: (1059,)

# %%
idx = 900
x = X[idx]
a = A[idx].todense()
y = Y[idx].todense()
seq_len = L[idx]   

a = a[:seq_len,:seq_len]
y = y[:seq_len,:seq_len]

# for debuging
plt.figure(figsize=(16,16))
plt.subplot(1,2,1)
plt.imshow(a)
plt.title("Normalized input adjacency matrix (local view)")
plt.ylabel("number of nodes")
plt.xlabel("number of nodes")
plt.subplot(1,2,2)
plt.imshow(y)
plt.title("Original adjacency matrix (wide view)")
plt.ylabel("number of nodes")
plt.xlabel("number of nodes")
plt.show()

# %%
import tensorflow as tf

max_len = HYPER_PARAMS["max_seq_length"]
ae_hidden = HYPER_PARAMS["ae_hidden"]

def weight_bias_vars(in_dim, out_dim):
    init_range = np.sqrt(6.0 / (in_dim + out_dim))
    initial = tf.random_uniform([in_dim, out_dim], minval=-init_range, maxval=init_range, dtype=tf.float32)
    return tf.Variable(initial)

def ae_layer(x, in_dim, out_dim):
    w = weight_bias_vars(in_dim, out_dim)
    x = tf.matmul(x,w)
    x = tf.keras.layers.BatchNormalization()(x)
    return x

def ae_model(a_in):
    encoder = ae_layer(a_in, max_len, ae_hidden)
    decoder = ae_layer(encoder, ae_hidden, max_len)
    return encoder, decoder

def get_pos_weight(mat):
    pos_w = float(mat.shape[0] * mat.shape[0] - mat.sum()) / mat.sum()
    return pos_w

def get_norm(mat):
    norm = mat.shape[0] * mat.shape[0] / float((mat.shape[0] * mat.shape[0] - mat.sum()) * 2)
    return norm

placeholders = {
    "X" : tf.sparse_placeholder(tf.float32),
    "A" : tf.sparse_placeholder(tf.float32),
    "Y" : tf.sparse_placeholder(tf.float32),
    "pos_weight": tf.placeholder(tf.float32),
    "norm" : tf.placeholder(tf.float32)
}

adj_in = tf.reshape(tf.sparse_tensor_to_dense(placeholders["A"] , validate_indices=False) ,
                    (max_len, max_len)) 

encoder, decoder = ae_model(adj_in)
decoder_flatten = tf.reshape(decoder, [-1])
decoder_sigmoid = tf.nn.sigmoid(decoder)

# %%
class OptimizerAE(object):
    def __init__(self, preds, labels, pos_weight, norm, lr):
        preds_sub = preds
        labels_sub = labels

        self.cost = norm * tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(logits=preds_sub,
                                                                                    targets=labels_sub, 
                                                                                    pos_weight=pos_weight))
        
        self.optimizer = tf.train.AdamOptimizer(learning_rate = lr) # Adam Optimizer
        self.opt_op = self.optimizer.minimize(self.cost)
        self.grads_vars = self.optimizer.compute_gradients(self.cost)
        self.correct_prediction = tf.equal(tf.cast(tf.greater_equal(tf.sigmoid(preds_sub), 0.5), tf.int32), 
                                           tf.cast(labels_sub, tf.int32))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))

opt = OptimizerAE(preds= decoder_flatten,
                  labels= tf.reshape(tf.sparse_tensor_to_dense(placeholders["Y"] , validate_indices=False) , [-1]),
                  pos_weight = placeholders["pos_weight"],
                  norm = placeholders["norm"],
                  lr = HYPER_PARAMS["learning_rate"])

# %%
# Initialize session
sess = tf.Session()
sess.run(tf.global_variables_initializer())
save_dir = HYPER_PARAMS["ae_model_dir"]
saver = tf.train.Saver()
checkpoint_path = os.path.join(save_dir, "ae_model")
ckpt = tf.train.get_checkpoint_state(save_dir)

IS_LOAD = True
if IS_LOAD and ckpt and ckpt.model_checkpoint_path:
    saver.restore(sess, ckpt.model_checkpoint_path)
    print("model_exist")

# %%
EPOCHS = HYPER_PARAMS["epochs"]
test_loss = 1
es_max = 100
ex_cnt = 0

for epoch in range(EPOCHS):
    
    train_rate   = 0.8
    train_len    = int(len(X) * train_rate)
    train_range  = range(0,train_len)
    test_range   = range(train_len,len(X))
    
    # TRAIN
    if not IS_LOAD:
        
        cost_list = []
        acc_list  = []

        for i in train_range:

            Y_tup = sparse_to_tuple(Y[i])

            feed_dict = {
                placeholders["A"]          : Y_tup,
                placeholders["Y"]          : Y_tup,
                placeholders["norm"]       : get_norm(Y[i]),
                placeholders["pos_weight"] : get_pos_weight(Y[i])
            }


            outs = sess.run([opt.opt_op, opt.cost, opt.accuracy], feed_dict=feed_dict)

            # Compute average loss
            avg_cost = outs[1]
            avg_accuracy = outs[2]

            cost_list.append(avg_cost)
            acc_list.append(avg_accuracy)

            if i % 50 == 0:
                print("Epoch {} ,batch({}/{}):".format(epoch+1 ,i+1, len(X)),
                      "train_loss={:.5f}".format(avg_cost), 
                      "train_acc={:.5f}".format(avg_accuracy))

        cost_list = np.array(cost_list)
        acc_list  = np.array(acc_list)
        print("-"*100)
        print(" ")
        print("Epoch {} results".format(epoch+1))
        print(">> average train loss = {:.5f}".format(np.mean(cost_list)))
        print(">> accuray train      = {:.5f}".format(np.mean(acc_list)))
        print(" ")
        print("="*100)
    
    
    # TEST 
    cost_list = []
    acc_list  = []
    
    for i in test_range:    
        
        Y_tup = sparse_to_tuple(Y[i])
        
        feed_dict = {
            placeholders["A"]          : Y_tup,
            placeholders["Y"]          : Y_tup,
            placeholders["norm"]       : get_norm(Y[i]),
            placeholders["pos_weight"] : get_pos_weight(Y[i])
        }
        
        outs = sess.run([opt.cost, opt.accuracy, decoder_sigmoid], feed_dict=feed_dict)

        # Compute average loss
        avg_cost     = outs[0]
        avg_accuracy = outs[1]
        
        cost_list.append(avg_cost)
        acc_list.append(avg_accuracy)
        
        if epoch % 2 == 0 and i % 100 == 0:
            
            # predictied result matrix
            P = outs[2]
            view_range = L[i]
            P = P[:view_range,:view_range]
            P_th = P > 0.5
            
            Y_t = Y[i].todense()
            Y_t = Y_t[:view_range,:view_range]
                        
            # for debuging
            plt.figure(figsize=(16,16))
            
            plt.subplot(1,3,1)
            plt.imshow(P)
            plt.title("Pred adjacency matrix (not thresholding)")
            plt.ylabel("number of nodes")
            plt.xlabel("number of nodes")
            
            plt.subplot(1,3,2)
            plt.imshow(P_th)
            plt.title("Pred adjacency matrix")
            plt.ylabel("number of nodes")
            plt.xlabel("number of nodes")
            
            plt.subplot(1,3,3)
            plt.imshow(Y_t)
            plt.title("True adjacency matrix")
            plt.ylabel("number of nodes")
            plt.xlabel("number of nodes")
            
            plt.show()
            
            print(">> test acc : ",avg_accuracy)
            
    
    cost_list = np.array(cost_list)
    acc_list  = np.array(acc_list)
    print("-"*100)
    print(" ")
    print("Epoch {} results".format(epoch+1))
    print(">> average test loss = {:.5f}".format(np.mean(cost_list)))
    print(">> accuray test      = {:.5f}".format(np.mean(acc_list)))
    print(" ")
    print("="*100)
    
    if not IS_LOAD:
        saver.save(sess, checkpoint_path)
        print("model saved")
        
    print('\n')
    
    
    if test_loss >= np.mean(cost_list) :
        test_loss = np.mean(cost_list)
        es_cnt = 0
    else:
        es_cnt += 1
        print("count++")
    
    if es_cnt == es_max:
        print("stop training epoch")
        break
        
    if IS_LOAD: break
# Out:
# Epoch 1 ,batch(1/1059): train_loss=0.69316 train_acc=0.49983
# Epoch 1 ,batch(51/1059): train_loss=0.61086 train_acc=0.64088
# Epoch 1 ,batch(101/1059): train_loss=0.40782 train_acc=0.70363
# Epoch 1 ,batch(151/1059): train_loss=0.20207 train_acc=0.98415
# Epoch 1 ,batch(201/1059): train_loss=0.07811 train_acc=0.99862
# Epoch 1 ,batch(251/1059): train_loss=0.04698 train_acc=0.99847
# Epoch 1 ,batch(301/1059): train_loss=0.02439 train_acc=0.99926
# Epoch 1 ,batch(351/1059): train_loss=0.01564 train_acc=0.99936
# Epoch 1 ,batch(401/1059): train_loss=0.03400 train_acc=0.99920
# Epoch 1 ,batch(451/1059): train_loss=0.00960 train_acc=0.99935
# Epoch 1 ,batch(501/1059): train_loss=0.03251 train_acc=0.99921
# Epoch 1 ,batch(551/1059): train_loss=0.00674 train_acc=0.99934
# Epoch 1 ,batch(601/1059): train_loss=0.00540 train_acc=0.99940
# Epoch 1 ,batch(651/1059): train_loss=0.00434 train_acc=0.99946
# Epoch 1 ,batch(701/1059): train_loss=0.02403 train_acc=0.99940
# Epoch 1 ,batch(751/1059): train_loss=0.00417 train_acc=0.99945
# Epoch 1 ,batch(801/1059): train_loss=0.00330 train_acc=0.99946
# ----------------------------------------------------------------------------------------------------
#
# Epoch 1 results
# >> average train loss = 0.10766
# >> accuray train      = 0.94882
#
# ====================================================================================================
# >> test acc :  0.99945825
# >> test acc :  0.9994628
# ----------------------------------------------------------------------------------------------------
#
# Epoch 1 results
# >> average test loss = 0.00588
# >> accuray test      = 0.99943
#
# ====================================================================================================
# model saved
#
#
# Epoch 2 ,batch(1/1059): train_loss=0.00296 train_acc=0.99946
# Epoch 2 ,batch(51/1059): train_loss=0.00297 train_acc=0.99945
# Epoch 2 ,batch(101/1059): train_loss=0.01939 train_acc=0.99942
# Epoch 2 ,batch(151/1059): train_loss=0.00251 train_acc=0.99947
# Epoch 2 ,batch(201/1059): train_loss=0.00221 train_acc=0.99949
# Epoch 2 ,batch(251/1059): train_loss=0.00331 train_acc=0.99913
# Epoch 2 ,batch(301/1059): train_loss=0.00232 train_acc=0.99946
# Epoch 2 ,batch(351/1059): train_loss=0.00194 train_acc=0.99950
# Epoch 2 ,batch(401/1059): train_loss=0.00429 train_acc=0.99934
# Epoch 2 ,batch(451/1059): train_loss=0.00181 train_acc=0.99950
# Epoch 2 ,batch(501/1059): train_loss=0.00712 train_acc=0.99936
# Epoch 2 ,batch(551/1059): train_loss=0.00165 train_acc=0.99951
# Epoch 2 ,batch(601/1059): train_loss=0.00149 train_acc=0.99952
# Epoch 2 ,batch(651/1059): train_loss=0.00127 train_acc=0.99955
# Epoch 2 ,batch(701/1059): train_loss=0.01558 train_acc=0.99952
# Epoch 2 ,batch(751/1059): train_loss=0.00137 train_acc=0.99955
# Epoch 2 ,batch(801/1059): train_loss=0.00116 train_acc=0.99955
# ----------------------------------------------------------------------------------------------------
#
# Epoch 2 results
# >> average train loss = 0.00296
# >> accuray train      = 0.99947
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 2 results
# >> average test loss = 0.00330
# >> accuray test      = 0.99954
#
# ====================================================================================================
# model saved
#
#
# Epoch 3 ,batch(1/1059): train_loss=0.00110 train_acc=0.99957
# Epoch 3 ,batch(51/1059): train_loss=0.00113 train_acc=0.99957
# Epoch 3 ,batch(101/1059): train_loss=0.01100 train_acc=0.99954
# Epoch 3 ,batch(151/1059): train_loss=0.00111 train_acc=0.99958
# Epoch 3 ,batch(201/1059): train_loss=0.00099 train_acc=0.99959
# Epoch 3 ,batch(251/1059): train_loss=0.00173 train_acc=0.99933
# Epoch 3 ,batch(301/1059): train_loss=0.00110 train_acc=0.99958
# Epoch 3 ,batch(351/1059): train_loss=0.00094 train_acc=0.99961
# Epoch 3 ,batch(401/1059): train_loss=0.00197 train_acc=0.99949
# Epoch 3 ,batch(451/1059): train_loss=0.00088 train_acc=0.99962
# Epoch 3 ,batch(501/1059): train_loss=0.00312 train_acc=0.99953
# Epoch 3 ,batch(551/1059): train_loss=0.00083 train_acc=0.99964
# Epoch 3 ,batch(601/1059): train_loss=0.00076 train_acc=0.99965
# Epoch 3 ,batch(651/1059): train_loss=0.00065 train_acc=0.99968
# Epoch 3 ,batch(701/1059): train_loss=0.00783 train_acc=0.99966
# Epoch 3 ,batch(751/1059): train_loss=0.00070 train_acc=0.99968
# Epoch 3 ,batch(801/1059): train_loss=0.00062 train_acc=0.99970
# ----------------------------------------------------------------------------------------------------
#
# Epoch 3 results
# >> average train loss = 0.00138
# >> accuray train      = 0.99960
#
# ====================================================================================================
# >> test acc :  0.999698
# >> test acc :  0.99969864
# ----------------------------------------------------------------------------------------------------
#
# Epoch 3 results
# >> average test loss = 0.00259
# >> accuray test      = 0.99968
#
# ====================================================================================================
# model saved
#
#
# Epoch 4 ,batch(1/1059): train_loss=0.00057 train_acc=0.99970
# Epoch 4 ,batch(51/1059): train_loss=0.00058 train_acc=0.99969
# Epoch 4 ,batch(101/1059): train_loss=0.00530 train_acc=0.99967
# Epoch 4 ,batch(151/1059): train_loss=0.00059 train_acc=0.99970
# Epoch 4 ,batch(201/1059): train_loss=0.00053 train_acc=0.99971
# Epoch 4 ,batch(251/1059): train_loss=0.00105 train_acc=0.99950
# Epoch 4 ,batch(301/1059): train_loss=0.00059 train_acc=0.99969
# Epoch 4 ,batch(351/1059): train_loss=0.00049 train_acc=0.99972
# Epoch 4 ,batch(401/1059): train_loss=0.00114 train_acc=0.99963
# Epoch 4 ,batch(451/1059): train_loss=0.00046 train_acc=0.99973
# Epoch 4 ,batch(501/1059): train_loss=0.00173 train_acc=0.99966
# Epoch 4 ,batch(551/1059): train_loss=0.00043 train_acc=0.99974
# Epoch 4 ,batch(601/1059): train_loss=0.00040 train_acc=0.99976
# Epoch 4 ,batch(651/1059): train_loss=0.00034 train_acc=0.99980
# Epoch 4 ,batch(701/1059): train_loss=0.00324 train_acc=0.99980
# Epoch 4 ,batch(751/1059): train_loss=0.00037 train_acc=0.99981
# Epoch 4 ,batch(801/1059): train_loss=0.00033 train_acc=0.99984
# ----------------------------------------------------------------------------------------------------
#
# Epoch 4 results
# >> average train loss = 0.00072
# >> accuray train      = 0.99972
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 4 results
# >> average test loss = 0.00235
# >> accuray test      = 0.99982
#
# ====================================================================================================
# model saved
#
#
# Epoch 5 ,batch(1/1059): train_loss=0.00029 train_acc=0.99984
# Epoch 5 ,batch(51/1059): train_loss=0.00029 train_acc=0.99982
# Epoch 5 ,batch(101/1059): train_loss=0.00239 train_acc=0.99978
# Epoch 5 ,batch(151/1059): train_loss=0.00029 train_acc=0.99982
# Epoch 5 ,batch(201/1059): train_loss=0.00026 train_acc=0.99985
# Epoch 5 ,batch(251/1059): train_loss=0.00063 train_acc=0.99964
# Epoch 5 ,batch(301/1059): train_loss=0.00030 train_acc=0.99983
# Epoch 5 ,batch(351/1059): train_loss=0.00024 train_acc=0.99986
# Epoch 5 ,batch(401/1059): train_loss=0.00065 train_acc=0.99976
# Epoch 5 ,batch(451/1059): train_loss=0.00022 train_acc=0.99989
# Epoch 5 ,batch(501/1059): train_loss=0.00097 train_acc=0.99979
# Epoch 5 ,batch(551/1059): train_loss=0.00020 train_acc=0.99990
# Epoch 5 ,batch(601/1059): train_loss=0.00019 train_acc=0.99991
# Epoch 5 ,batch(651/1059): train_loss=0.00016 train_acc=0.99994
# Epoch 5 ,batch(701/1059): train_loss=0.00136 train_acc=0.99993
# Epoch 5 ,batch(751/1059): train_loss=0.00019 train_acc=0.99995
# Epoch 5 ,batch(801/1059): train_loss=0.00016 train_acc=0.99996
# ----------------------------------------------------------------------------------------------------
#
# Epoch 5 results
# >> average train loss = 0.00036
# >> accuray train      = 0.99986
#
# ====================================================================================================
# >> test acc :  0.9999644
# >> test acc :  0.9999647
# ----------------------------------------------------------------------------------------------------
#
# Epoch 5 results
# >> average test loss = 0.00226
# >> accuray test      = 0.99994
#
# ====================================================================================================
# model saved
#
#
# Epoch 6 ,batch(1/1059): train_loss=0.00013 train_acc=0.99997
# Epoch 6 ,batch(51/1059): train_loss=0.00013 train_acc=0.99996
# Epoch 6 ,batch(101/1059): train_loss=0.00108 train_acc=0.99993
# Epoch 6 ,batch(151/1059): train_loss=0.00013 train_acc=0.99997
# Epoch 6 ,batch(201/1059): train_loss=0.00012 train_acc=0.99998
# Epoch 6 ,batch(251/1059): train_loss=0.00037 train_acc=0.99979
# Epoch 6 ,batch(301/1059): train_loss=0.00014 train_acc=0.99996
# Epoch 6 ,batch(351/1059): train_loss=0.00011 train_acc=0.99998
# Epoch 6 ,batch(401/1059): train_loss=0.00037 train_acc=0.99987
# Epoch 6 ,batch(451/1059): train_loss=0.00010 train_acc=0.99999
# Epoch 6 ,batch(501/1059): train_loss=0.00053 train_acc=0.99990
# Epoch 6 ,batch(551/1059): train_loss=0.00009 train_acc=0.99999
# Epoch 6 ,batch(601/1059): train_loss=0.00009 train_acc=0.99999
# Epoch 6 ,batch(651/1059): train_loss=0.00007 train_acc=1.00000
# Epoch 6 ,batch(701/1059): train_loss=0.00067 train_acc=0.99997
# Epoch 6 ,batch(751/1059): train_loss=0.00009 train_acc=0.99999
# Epoch 6 ,batch(801/1059): train_loss=0.00008 train_acc=0.99999
# ----------------------------------------------------------------------------------------------------
#
# Epoch 6 results
# >> average train loss = 0.00018
# >> accuray train      = 0.99996
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 6 results
# >> average test loss = 0.00225
# >> accuray test      = 0.99998
#
# ====================================================================================================
# model saved
#
#
# Epoch 7 ,batch(1/1059): train_loss=0.00006 train_acc=1.00000
# Epoch 7 ,batch(51/1059): train_loss=0.00006 train_acc=1.00000
# Epoch 7 ,batch(101/1059): train_loss=0.00053 train_acc=0.99998
# Epoch 7 ,batch(151/1059): train_loss=0.00006 train_acc=1.00000
# Epoch 7 ,batch(201/1059): train_loss=0.00005 train_acc=1.00000
# Epoch 7 ,batch(251/1059): train_loss=0.00022 train_acc=0.99988
# Epoch 7 ,batch(301/1059): train_loss=0.00007 train_acc=0.99999
# Epoch 7 ,batch(351/1059): train_loss=0.00005 train_acc=1.00000
# Epoch 7 ,batch(401/1059): train_loss=0.00022 train_acc=0.99992
# Epoch 7 ,batch(451/1059): train_loss=0.00005 train_acc=1.00000
# Epoch 7 ,batch(501/1059): train_loss=0.00030 train_acc=0.99995
# Epoch 7 ,batch(551/1059): train_loss=0.00004 train_acc=1.00000
# Epoch 7 ,batch(601/1059): train_loss=0.00004 train_acc=1.00000
# Epoch 7 ,batch(651/1059): train_loss=0.00004 train_acc=1.00000
# Epoch 7 ,batch(701/1059): train_loss=0.00036 train_acc=0.99998
# Epoch 7 ,batch(751/1059): train_loss=0.00005 train_acc=1.00000
# Epoch 7 ,batch(801/1059): train_loss=0.00004 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 7 results
# >> average train loss = 0.00009
# >> accuray train      = 0.99998
#
# ====================================================================================================
# >> test acc :  0.9999988
# >> test acc :  0.9999994
# ----------------------------------------------------------------------------------------------------
#
# Epoch 7 results
# >> average test loss = 0.00230
# >> accuray test      = 0.99999
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 8 ,batch(1/1059): train_loss=0.00003 train_acc=1.00000
# Epoch 8 ,batch(51/1059): train_loss=0.00003 train_acc=1.00000
# Epoch 8 ,batch(101/1059): train_loss=0.00029 train_acc=0.99999
# Epoch 8 ,batch(151/1059): train_loss=0.00003 train_acc=1.00000
# Epoch 8 ,batch(201/1059): train_loss=0.00003 train_acc=1.00000
# Epoch 8 ,batch(251/1059): train_loss=0.00014 train_acc=0.99993
# Epoch 8 ,batch(301/1059): train_loss=0.00004 train_acc=1.00000
# Epoch 8 ,batch(351/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 8 ,batch(401/1059): train_loss=0.00014 train_acc=0.99994
# Epoch 8 ,batch(451/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 8 ,batch(501/1059): train_loss=0.00018 train_acc=0.99996
# Epoch 8 ,batch(551/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 8 ,batch(601/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 8 ,batch(651/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 8 ,batch(701/1059): train_loss=0.00021 train_acc=0.99999
# Epoch 8 ,batch(751/1059): train_loss=0.00003 train_acc=1.00000
# Epoch 8 ,batch(801/1059): train_loss=0.00002 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 8 results
# >> average train loss = 0.00005
# >> accuray train      = 0.99999
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 8 results
# >> average test loss = 0.00240
# >> accuray test      = 0.99999
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 9 ,batch(1/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 9 ,batch(51/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 9 ,batch(101/1059): train_loss=0.00017 train_acc=0.99999
# Epoch 9 ,batch(151/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 9 ,batch(201/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 9 ,batch(251/1059): train_loss=0.00008 train_acc=0.99996
# Epoch 9 ,batch(301/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 9 ,batch(351/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 9 ,batch(401/1059): train_loss=0.00009 train_acc=0.99996
# Epoch 9 ,batch(451/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 9 ,batch(501/1059): train_loss=0.00012 train_acc=0.99997
# Epoch 9 ,batch(551/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 9 ,batch(601/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 9 ,batch(651/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 9 ,batch(701/1059): train_loss=0.00013 train_acc=0.99999
# Epoch 9 ,batch(751/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 9 ,batch(801/1059): train_loss=0.00001 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 9 results
# >> average train loss = 0.00003
# >> accuray train      = 0.99999
#
# ====================================================================================================
# >> test acc :  0.9999997
# >> test acc :  0.9999999
# ----------------------------------------------------------------------------------------------------
#
# Epoch 9 results
# >> average test loss = 0.00252
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 10 ,batch(1/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(51/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(101/1059): train_loss=0.00010 train_acc=0.99999
# Epoch 10 ,batch(151/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(201/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(251/1059): train_loss=0.00005 train_acc=0.99998
# Epoch 10 ,batch(301/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(351/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(401/1059): train_loss=0.00006 train_acc=0.99998
# Epoch 10 ,batch(451/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(501/1059): train_loss=0.00008 train_acc=0.99998
# Epoch 10 ,batch(551/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(601/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(651/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(701/1059): train_loss=0.00008 train_acc=0.99999
# Epoch 10 ,batch(751/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 10 ,batch(801/1059): train_loss=0.00001 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 10 results
# >> average train loss = 0.00002
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 10 results
# >> average test loss = 0.00265
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 11 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(101/1059): train_loss=0.00006 train_acc=0.99999
# Epoch 11 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(251/1059): train_loss=0.00003 train_acc=1.00000
# Epoch 11 ,batch(301/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 11 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(401/1059): train_loss=0.00003 train_acc=0.99999
# Epoch 11 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(501/1059): train_loss=0.00005 train_acc=0.99998
# Epoch 11 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 11 ,batch(701/1059): train_loss=0.00005 train_acc=0.99999
# Epoch 11 ,batch(751/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 11 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 11 results
# >> average train loss = 0.00001
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  0.99999994
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 11 results
# >> average test loss = 0.00277
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 12 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(101/1059): train_loss=0.00004 train_acc=1.00000
# Epoch 12 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(251/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 12 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(401/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 12 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(501/1059): train_loss=0.00003 train_acc=0.99999
# Epoch 12 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(701/1059): train_loss=0.00003 train_acc=1.00000
# Epoch 12 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 12 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 12 results
# >> average train loss = 0.00001
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 12 results
# >> average test loss = 0.00289
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 13 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(101/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 13 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(251/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 13 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(401/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 13 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(501/1059): train_loss=0.00002 train_acc=0.99999
# Epoch 13 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(701/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 13 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 13 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 13 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 13 results
# >> average test loss = 0.00301
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 14 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(101/1059): train_loss=0.00002 train_acc=1.00000
# Epoch 14 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(251/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 14 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(401/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 14 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(501/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 14 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(701/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 14 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 14 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 14 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 14 results
# >> average test loss = 0.00313
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 15 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(101/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 15 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(501/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 15 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(701/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 15 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 15 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 15 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 15 results
# >> average test loss = 0.00325
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 16 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(101/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 16 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(501/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 16 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(701/1059): train_loss=0.00001 train_acc=1.00000
# Epoch 16 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 16 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 16 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 16 results
# >> average test loss = 0.00336
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 17 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 17 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 17 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 17 results
# >> average test loss = 0.00347
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 18 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 18 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 18 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 18 results
# >> average test loss = 0.00358
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 19 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 19 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 19 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 19 results
# >> average test loss = 0.00368
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 20 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 20 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 20 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 20 results
# >> average test loss = 0.00379
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 21 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 21 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 21 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 21 results
# >> average test loss = 0.00390
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 22 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 22 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 22 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 22 results
# >> average test loss = 0.00401
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 23 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 23 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 23 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 23 results
# >> average test loss = 0.00413
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 24 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 24 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 24 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 24 results
# >> average test loss = 0.00425
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 25 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 25 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 25 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 25 results
# >> average test loss = 0.00438
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 26 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 26 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 26 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 26 results
# >> average test loss = 0.00451
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 27 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 27 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 27 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 27 results
# >> average test loss = 0.00464
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 28 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 28 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 28 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 28 results
# >> average test loss = 0.00476
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 29 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 29 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 29 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 29 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 29 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 29 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 29 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 29 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 29 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# ...
# Epoch 91 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 91 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 91 results
# >> average test loss = 0.00653
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 92 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 92 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 92 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 92 results
# >> average test loss = 0.00653
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 93 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 93 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 93 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 93 results
# >> average test loss = 0.00654
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 94 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 94 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 94 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 94 results
# >> average test loss = 0.00655
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 95 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 95 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 95 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 95 results
# >> average test loss = 0.00656
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 96 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 96 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 96 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 96 results
# >> average test loss = 0.00657
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 97 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 97 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 97 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 97 results
# >> average test loss = 0.00657
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 98 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 98 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 98 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 98 results
# >> average test loss = 0.00658
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 99 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 99 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 99 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# >> test acc :  1.0
# >> test acc :  1.0
# ----------------------------------------------------------------------------------------------------
#
# Epoch 99 results
# >> average test loss = 0.00659
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
# Epoch 100 ,batch(1/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(51/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(101/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(151/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(201/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(251/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(301/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(351/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(401/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(451/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(501/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(551/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(601/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(651/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(701/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(751/1059): train_loss=0.00000 train_acc=1.00000
# Epoch 100 ,batch(801/1059): train_loss=0.00000 train_acc=1.00000
# ----------------------------------------------------------------------------------------------------
#
# Epoch 100 results
# >> average train loss = 0.00000
# >> accuray train      = 1.00000
#
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
#
# Epoch 100 results
# >> average test loss = 0.00660
# >> accuray test      = 1.00000
#
# ====================================================================================================
# model saved
#
#
# count++
